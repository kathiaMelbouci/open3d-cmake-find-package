# %% [markdown]
# <a href="https://colab.research.google.com/github/kathiaMelbouci/open3d-cmake-find-package/blob/master/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8bdc5387-222b-4cec-98bd-6a937220dc40" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8bdc5387-222b-4cec-98bd-6a937220dc40">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip on_attentions_for_pcds.zip
# Out:
# Archive:  on_attentions_for_pcds.zip
#    creating: on_attentions_for_pcds/
#    creating: on_attentions_for_pcds/models/
#   inflating: on_attentions_for_pcds/models/executor.py
#    creating: on_attentions_for_pcds/models/__pycache__/
#   inflating: on_attentions_for_pcds/models/__pycache__/executor.cpython-39.pyc
#   inflating: on_attentions_for_pcds/models/__pycache__/posesdecoder_model.cpython-39.pyc
#   inflating: on_attentions_for_pcds/models/__pycache__/base_model.cpython-39.pyc
#   inflating: on_attentions_for_pcds/models/__pycache__/__init__.cpython-39.pyc
#   inflating: on_attentions_for_pcds/models/__pycache__/pcdencoder_model.cpython-39.pyc
#   inflating: on_attentions_for_pcds/models/posesdecoder_model.py
#   inflating: on_attentions_for_pcds/models/pcdencoder_model.py
#  extracting: on_attentions_for_pcds/models/__init__.py
#    creating: on_attentions_for_pcds/config/
#   inflating: on_attentions_for_pcds/config/config.yaml
# ...
